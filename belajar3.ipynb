# %% [markdown]
# <a href="https://colab.research.google.com/github/AlvinDefanno/Pyton-for-Database/blob/main/belajar3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.path
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
import pandas as pd

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
a = first_df=pd.DataFrame({'person':['oranga','orangb'],'pay':[50,30]})
a
# Out:
#    person  pay
# 0  oranga   50
# 1  orangb   30

# %%
a = first_df=pd.DataFrame({'person':['oranga','orangb'],'pay':[50,30]}, index=['produk_1','produk_2'])
a
# Out:
#           person  pay
# produk_1  oranga   50
# produk_2  orangb   30

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series([1,2,3, 4,5], index=['Sales 1','Sales 2','Sales3', 'Sales 4','Sales5'])
# Out:
# Sales 1    1
# Sales 2    2
# Sales3     3
# Sales 4    4
# Sales5     5
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv("/Pandas/iris_concat_1.csv")
df
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1            5.1           3.5            1.4           0.2
# 1    2            4.9           3.0            1.4           0.2
# 2    3            4.7           3.2            1.3           0.2
# 3    4            4.6           3.1            1.5           0.2
# 4    5            5.0           3.6            1.4           0.2
# ..  ..            ...           ...            ...           ...
# 84  85            5.4           3.0            4.5           1.5
# 85  86            6.0           3.4            4.5           1.6
# 86  87            6.7           3.1            4.7           1.5
# 87  88            6.3           2.3            4.4           1.3
# 88  89            5.6           3.0            4.1           1.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 84  Iris-versicolor
# ...

# %%
df.shape
# Out:
# (89, 6)

# %%
len(df)
# Out:
# 89

# %%
df.head(6)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa

# %%
df.tail(6)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 83  84            6.0           2.7            5.1           1.6
# 84  85            5.4           3.0            4.5           1.5
# 85  86            6.0           3.4            4.5           1.6
# 86  87            6.7           3.1            4.7           1.5
# 87  88            6.3           2.3            4.4           1.3
# 88  89            5.6           3.0            4.1           1.3
#
#             Species
# 83  Iris-versicolor
# 84  Iris-versicolor
# 85  Iris-versicolor
# 86  Iris-versicolor
# 87  Iris-versicolor
# 88  Iris-versicolor

# %%
df['Species']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#            ...
# 84    Iris-versicolor
# 85    Iris-versicolor
# 86    Iris-versicolor
# 87    Iris-versicolor
# 88    Iris-versicolor
# Name: Species, Length: 89, dtype: object

# %%
df['Species'][88]
# Out:
# 'Iris-versicolor'

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df['PetalLengthCm'].dtype
# Out:
# dtype('float64')

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df['Species'].describe()
# Out:
# count              89
# unique              2
# top       Iris-setosa
# freq               50
# Name: Species, dtype: object

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor'], dtype=object)

# %%
df['Species'].nunique()
# Out:
# 2

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    39
# Name: Species, dtype: int64

# %%
df.count()
# Out:
# Id               89
# SepalLengthCm    87
# SepalWidthCm     89
# PetalLengthCm    89
# PetalWidthCm     89
# Species          89
# dtype: int64

# %%
df.groupby(by='Species').sum(id)
# Out:
#                    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa      1275          239.7         170.9           73.2
# Iris-versicolor  2730          234.9         108.7          168.7
#
#                  PetalWidthCm
# Species
# Iris-setosa              12.2
# Iris-versicolor          52.7

# %%
df.iloc[5]
# Out:
# Id                         6
# SepalLengthCm            5.4
# SepalWidthCm             3.9
# PetalLengthCm            1.7
# PetalWidthCm             0.4
# Species          Iris-setosa
# Name: 5, dtype: object

# %%
df.iloc[:,3]
# Out:
# 0     1.4
# 1     1.4
# 2     1.3
# 3     1.5
# 4     1.4
#      ...
# 84    4.5
# 85    4.5
# 86    4.7
# 87    4.4
# 88    4.1
# Name: PetalLengthCm, Length: 89, dtype: float64

# %%
df.iloc[1:3,:]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
df.loc[33,'Species']
# Out:
# 'Iris-setosa'

# %%
df.loc[5:,['Species','PetalWidthCm']]
# Out:
#             Species  PetalWidthCm
# 5       Iris-setosa           0.4
# 6       Iris-setosa           0.3
# 7       Iris-setosa           0.2
# 8       Iris-setosa           0.2
# 9       Iris-setosa           0.1
# ..              ...           ...
# 84  Iris-versicolor           1.5
# 85  Iris-versicolor           1.6
# 86  Iris-versicolor           1.5
# 87  Iris-versicolor           1.3
# 88  Iris-versicolor           1.3
#
# [84 rows x 2 columns]

# %%
df.set_index('Id')
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# Id
# 1             5.1           3.5            1.4           0.2      Iris-setosa
# 2             4.9           3.0            1.4           0.2      Iris-setosa
# 3             4.7           3.2            1.3           0.2      Iris-setosa
# 4             4.6           3.1            1.5           0.2      Iris-setosa
# 5             5.0           3.6            1.4           0.2      Iris-setosa
# ..            ...           ...            ...           ...              ...
# 85            5.4           3.0            4.5           1.5  Iris-versicolor
# 86            6.0           3.4            4.5           1.6  Iris-versicolor
# 87            6.7           3.1            4.7           1.5  Iris-versicolor
# 88            6.3           2.3            4.4           1.3  Iris-versicolor
# 89            5.6           3.0            4.1           1.3  Iris-versicolor
#
# [89 rows x 5 columns]

# %%
df['Species'] == 'Iris-versicolor'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 84     True
# 85     True
# 86     True
# 87     True
# 88     True
# Name: Species, Length: 89, dtype: bool

# %%
df[(df['SepalLengthCm'] > 3) & (df['Species'] == 'Iris-versicolor')]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50  51            7.0           3.2            4.7           1.4
# 51  52            6.4           3.2            4.5           1.5
# 52  53            6.9           3.1            4.9           1.5
# 53  54            5.5           2.3            4.0           1.3
# 54  55            6.5           2.8            4.6           1.5
# 55  56            5.7           2.8            4.5           1.3
# 56  57            6.3           3.3            4.7           1.6
# 57  58            4.9           2.4            3.3           1.0
# 58  59            6.6           2.9            4.6           1.3
# 59  60            5.2           2.7            3.9           1.4
# 60  61            5.0           2.0            3.5           1.0
# 61  62            5.9           3.0            4.2           1.5
# 62  63            6.0           2.2            4.0           1.0
# ...

# %%
df[df['Species'].isin(['Iris-versicolor','Irisvirginica'])]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50  51            7.0           3.2            4.7           1.4
# 51  52            6.4           3.2            4.5           1.5
# 52  53            6.9           3.1            4.9           1.5
# 53  54            5.5           2.3            4.0           1.3
# 54  55            6.5           2.8            4.6           1.5
# 55  56            5.7           2.8            4.5           1.3
# 56  57            6.3           3.3            4.7           1.6
# 57  58            4.9           2.4            3.3           1.0
# 58  59            6.6           2.9            4.6           1.3
# 59  60            5.2           2.7            3.9           1.4
# 60  61            5.0           2.0            3.5           1.0
# 61  62            5.9           3.0            4.2           1.5
# 62  63            6.0           2.2            4.0           1.0
# ...

# %%
filter = df['SepalLengthCm'] > 4
df.where(filter)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1            5.1           3.5            1.4           0.2
# 1    2            4.9           3.0            1.4           0.2
# 2    3            4.7           3.2            1.3           0.2
# 3    4            4.6           3.1            1.5           0.2
# 4    5            5.0           3.6            1.4           0.2
# ..  ..            ...           ...            ...           ...
# 84  85            5.4           3.0            4.5           1.5
# 85  86            6.0           3.4            4.5           1.6
# 86  87            6.7           3.1            4.7           1.5
# 87  88            6.3           2.3            4.4           1.3
# 88  89            5.6           3.0            4.1           1.3
#
#             Species  PetalArea
# 0       Iris-setosa      0.140
# 1       Iris-setosa      0.140
# 2       Iris-setosa      0.130
# 3       Iris-setosa      0.150
# ...

# %%
dataframe_1 = pd.DataFrame([['a', 1], ['b', 2]],columns=['letter', 'number'])
dataframe_1
# Out:
#   letter  number
# 0      a       1
# 1      b       2

# %%
dataframe_2 = pd.DataFrame([['c', 4], ['a', 4]],columns=['letter', 'number'])
dataframe_2
# Out:
#   letter  number
# 0      c       4
# 1      a       4

# %%
pd.concat([dataframe_1,dataframe_2],axis =0)
# Out:
#   letter  number
# 0      a       1
# 1      b       2
# 0      c       4
# 1      a       4

# %%
pd.concat([dataframe_1,dataframe_2],axis =1)
# Out:
#   letter  number letter  number
# 0      a       1      c       4
# 1      b       2      a       4

# %%
dataframe_1=pd.DataFrame({'key': ['K0','K1','K2','K3','K4','K5'],"A" :['A0','A1','A2','A3','A4','A5']})
dataframe_1
# Out:
#   key   A
# 0  K0  A0
# 1  K1  A1
# 2  K2  A2
# 3  K3  A3
# 4  K4  A4
# 5  K5  A5

# %%
dataframe_2=pd.DataFrame({'key': ['K0','K1','K2'],"B": ['B0','B1','B2']})
dataframe_2
# Out:
#   key   B
# 0  K0  B0
# 1  K1  B1
# 2  K2  B2

# %%
dataframe_1.join(dataframe_2,how='left',lsuffix='_1',rsuffix='_2')
# Out:
#   key_1   A key_2    B
# 0    K0  A0    K0   B0
# 1    K1  A1    K1   B1
# 2    K2  A2    K2   B2
# 3    K3  A3   NaN  NaN
# 4    K4  A4   NaN  NaN
# 5    K5  A5   NaN  NaN

# %%
df['Species'].astype(str)
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#            ...
# 84    Iris-versicolor
# 85    Iris-versicolor
# 86    Iris-versicolor
# 87    Iris-versicolor
# 88    Iris-versicolor
# Name: Species, Length: 89, dtype: object

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    2
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             89 non-null     int64
#  1   SepalLengthCm  87 non-null     float64
#  2   SepalWidthCm   89 non-null     float64
#  3   PetalLengthCm  89 non-null     float64
#  4   PetalWidthCm   89 non-null     float64
#  5   Species        89 non-null     object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 4.3+ KB

# %%
a= df['SepalLengthCm']=df['SepalLengthCm'].fillna(df['SepalLengthCm'].mean())
a
# Out:
# 0     5.1
# 1     4.9
# 2     4.7
# 3     4.6
# 4     5.0
#      ...
# 84    5.4
# 85    6.0
# 86    6.7
# 87    6.3
# 88    5.6
# Name: SepalLengthCm, Length: 89, dtype: float64

# %%
df
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1            5.1           3.5            1.4           0.2
# 1    2            4.9           3.0            1.4           0.2
# 2    3            4.7           3.2            1.3           0.2
# 3    4            4.6           3.1            1.5           0.2
# 4    5            5.0           3.6            1.4           0.2
# ..  ..            ...           ...            ...           ...
# 84  85            5.4           3.0            4.5           1.5
# 85  86            6.0           3.4            4.5           1.6
# 86  87            6.7           3.1            4.7           1.5
# 87  88            6.3           2.3            4.4           1.3
# 88  89            5.6           3.0            4.1           1.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 84  Iris-versicolor
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1            5.1           3.5            1.4           0.2
# 1    2            4.9           3.0            1.4           0.2
# 2    3            4.7           3.2            1.3           0.2
# 3    4            4.6           3.1            1.5           0.2
# 4    5            5.0           3.6            1.4           0.2
# ..  ..            ...           ...            ...           ...
# 84  85            5.4           3.0            4.5           1.5
# 85  86            6.0           3.4            4.5           1.6
# 86  87            6.7           3.1            4.7           1.5
# 87  88            6.3           2.3            4.4           1.3
# 88  89            5.6           3.0            4.1           1.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 84  Iris-versicolor
# ...

# %%
df.drop(0, axis = 0)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 1    2            4.9           3.0            1.4           0.2
# 2    3            4.7           3.2            1.3           0.2
# 3    4            4.6           3.1            1.5           0.2
# 4    5            5.0           3.6            1.4           0.2
# 5    6            5.4           3.9            1.7           0.4
# ..  ..            ...           ...            ...           ...
# 84  85            5.4           3.0            4.5           1.5
# 85  86            6.0           3.4            4.5           1.6
# 86  87            6.7           3.1            4.7           1.5
# 87  88            6.3           2.3            4.4           1.3
# 88  89            5.6           3.0            4.1           1.3
#
#             Species
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# ..              ...
# 84  Iris-versicolor
# ...

# %%
df.drop([0,1,2,3,4], axis = 0)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 5    6            5.4           3.9            1.7           0.4
# 6    7            4.6           3.4            1.4           0.3
# 7    8            5.0           3.4            1.5           0.2
# 8    9            4.4           2.9            1.4           0.2
# 9   10            4.9           3.1            1.5           0.1
# ..  ..            ...           ...            ...           ...
# 84  85            5.4           3.0            4.5           1.5
# 85  86            6.0           3.4            4.5           1.6
# 86  87            6.7           3.1            4.7           1.5
# 87  88            6.3           2.3            4.4           1.3
# 88  89            5.6           3.0            4.1           1.3
#
#             Species
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# ..              ...
# 84  Iris-versicolor
# ...

# %%
df.sort_values(by="SepalWidthCm", ascending=True)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 60  61       5.000000           2.0            3.5           1.0
# 62  63       6.000000           2.2            4.0           1.0
# 68  69       6.200000           2.2            4.5           1.5
# 53  54       5.500000           2.3            4.0           1.3
# 87  88       6.300000           2.3            4.4           1.3
# ..  ..            ...           ...            ...           ...
# 5    6       5.400000           3.9            1.7           0.4
# 14  15       5.800000           4.0            1.2           0.2
# 32  33       5.200000           4.1            1.5           0.1
# 33  34       5.455172           4.2            1.4           0.2
# 15  16       5.700000           4.4            1.5           0.4
#
#             Species
# 60  Iris-versicolor
# 62  Iris-versicolor
# 68  Iris-versicolor
# 53  Iris-versicolor
# 87  Iris-versicolor
# ..              ...
# 5       Iris-setosa
# ...

# %%
df.sort_values(by="SepalWidthCm", ascending=True).reset_index()
# Out:
#     index  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      60  61       5.000000           2.0            3.5           1.0
# 1      62  63       6.000000           2.2            4.0           1.0
# 2      68  69       6.200000           2.2            4.5           1.5
# 3      53  54       5.500000           2.3            4.0           1.3
# 4      87  88       6.300000           2.3            4.4           1.3
# ..    ...  ..            ...           ...            ...           ...
# 84      5   6       5.400000           3.9            1.7           0.4
# 85     14  15       5.800000           4.0            1.2           0.2
# 86     32  33       5.200000           4.1            1.5           0.1
# 87     33  34       5.455172           4.2            1.4           0.2
# 88     15  16       5.700000           4.4            1.5           0.4
#
#             Species
# 0   Iris-versicolor
# 1   Iris-versicolor
# 2   Iris-versicolor
# ...

# %%
df["PetalArea"]= 0.5 * df["PetalWidthCm"] * df["PetalLengthCm"]
df
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1            5.1           3.5            1.4           0.2
# 1    2            4.9           3.0            1.4           0.2
# 2    3            4.7           3.2            1.3           0.2
# 3    4            4.6           3.1            1.5           0.2
# 4    5            5.0           3.6            1.4           0.2
# ..  ..            ...           ...            ...           ...
# 84  85            5.4           3.0            4.5           1.5
# 85  86            6.0           3.4            4.5           1.6
# 86  87            6.7           3.1            4.7           1.5
# 87  88            6.3           2.3            4.4           1.3
# 88  89            5.6           3.0            4.1           1.3
#
#             Species  PetalArea
# 0       Iris-setosa      0.140
# 1       Iris-setosa      0.140
# 2       Iris-setosa      0.130
# 3       Iris-setosa      0.150
# ...

# %%
df.rename(columns = {'SepalLengthCm': 'Data_1','SepalWidthCm': 'Data_2', 'PetalLengthCm':'Data_3','PetalWidthCm':'Data_4','Species':'Data_5','PetalArea':'Data_6'})
# Out:
#     Id  Data_1  Data_2  Data_3  Data_4           Data_5  Data_6
# 0    1     5.1     3.5     1.4     0.2      Iris-setosa   0.140
# 1    2     4.9     3.0     1.4     0.2      Iris-setosa   0.140
# 2    3     4.7     3.2     1.3     0.2      Iris-setosa   0.130
# 3    4     4.6     3.1     1.5     0.2      Iris-setosa   0.150
# 4    5     5.0     3.6     1.4     0.2      Iris-setosa   0.140
# ..  ..     ...     ...     ...     ...              ...     ...
# 84  85     5.4     3.0     4.5     1.5  Iris-versicolor   3.375
# 85  86     6.0     3.4     4.5     1.6  Iris-versicolor   3.600
# 86  87     6.7     3.1     4.7     1.5  Iris-versicolor   3.525
# 87  88     6.3     2.3     4.4     1.3  Iris-versicolor   2.860
# 88  89     5.6     3.0     4.1     1.3  Iris-versicolor   2.665
#
# [89 rows x 7 columns]
